# %% [markdown]
# <a href="https://colab.research.google.com/github/shal-inimoorthy/python/blob/main/Potholes%26bumps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !git clone "https://github.com/AlexeyAB/darknet.git"

# %%
# %cd /content/darknet

# %%
# !make

# %%
# !./darknet

# %%
# !cp -r '/content/drive/MyDrive/test_images.zip' '/content'

# %%
# %cd /content

# %%
# !unzip "/content/test_images.zip"
# Out:
# unzip:  cannot find or open /content/test_images.zip, /content/test_images.zip.zip or /content/test_images.zip.ZIP.

# %%
# !cp /content/test_images.zip

# %%
# !cp /content/test_images/*.txt /content/darknet/data/custom

# %%
# %cd /content/darknet

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.conv.29

# %%
# %cd /content/darknet/data

# %%
# !python pr.py

# %%
# %cd /content/darknet

# %%
# !./darknet detector train /content/darknet/cfg/objects.data /content/darknet/cfg/yolov4-tiny.cfg /content/darknet/yolov4-tiny.conv.29 -dont_show -clear
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.893240), count: 95, class_loss = 0.090664, iou_loss = 5.440871, total_loss = 5.531535
#  total_bbox = 983078, rewritten_bbox = 0.176893 %
#
#  Tensor Cores are used.
#
#  5377: 0.072200, 0.049957 avg loss, 0.000026 rate, 0.665996 seconds, 344128 images, 0.136063 hours left
# Loaded: 0.000078 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.900540), count: 105, class_loss = 0.036165, iou_loss = 1.635126, total_loss = 1.671291
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.907248), count: 104, class_loss = 0.031036, iou_loss = 6.528972, total_loss = 6.560008
#  total_bbox = 983287, rewritten_bbox = 0.176856 %
#
#  Tensor Cores are used.
#
#  5378: 0.033705, 0.048332 avg loss, 0.000026 rate, 0.687513 seconds, 344192 images, 0.135855 hours left
# Loaded: 0.000082 seconds
# ...
